# %% [markdown]
# Fetching Data from APIs, and Loading CSV/JSON Files

# %% [markdown]
# Amani Insurance claims case study

# %% [markdown]
# Deliverable: Fetching data from APIs and load CSV or JSON files.

# %% [markdown]
# Business scenario: Amani Insurance cedes (shares) a portion of its large property and motor-theft claims with an international reinsurer who prices everything in USD. To report ceded claims correctly, Amani needs the current USD/KES exchange rate.
#
# This notebook:
#
# 1.Loads the claims CSV (familiar by now) and a JSON policyholder master file (new).
# 2.Fetches a live USD/KES exchange rate from a free, keyless public API.
# 3.Falls back to a small cached JSON file automatically if there's no internet.
# 4.Joins claims + policyholders + exchange rate into one view, and reports ceded claims in both KES and USD.
# 5.Requires the requests library (pip install requests).

# %%
import json

import pandas as pd
import requests

CLAIMS_PATH = "insurance_claims_messy.csv"
POLICYHOLDERS_PATH = "policyholders.json"
FALLBACK_RATES_PATH = "exchange_rates_cache.json"

API_URL = "https://api.frankfurter.app/latest"
# NOTE: if your network blocks this URL, or there's no wifi, the fallback
# further down kicks in automatically -- the notebook still runs either way

# %%
claims = pd.read_csv(CLAIMS_PATH)
print(f"claims: {claims.shape[0]} rows from CSV")
# Out:
# claims: 509 rows from CSV

# %%
# json.load() reads the file into plain Python objects -- here, a list of dicts.
with open(POLICYHOLDERS_PATH, "r", encoding="utf-8") as f:
    policyholders_raw = json.load(f)

print(f"policyholders_raw is a {type(policyholders_raw).__name__} of {len(policyholders_raw)} dicts.")
print("First record:")
policyholders_raw[0]
# Out:
# policyholders_raw is a list of 220 dicts.
# First record:
# {'policy_number': 'AMI-00001',
#  'full_name': 'Dennis Onyango',
#  'age': 32,
#  'gender': 'M',
#  'cover_type': 'Property Cover',
#  'sum_insured_kes': 500000,
#  'region': 'Eldoret',
#  'join_date': '2020-11-23'}

# %%
# pd.read_json() skips the intermediate step and goes straight to a DataFrame,
# since this JSON file is already a flat list of same-shaped records.
policyholders = pd.read_json(POLICYHOLDERS_PATH)
print(f"policyholders DataFrame: {policyholders.shape}")
policyholders.head(5)
# Out:
# policyholders DataFrame: (220, 8)
#   policy_number       full_name   age gender         cover_type  \
# 0     AMI-00001  Dennis Onyango  32.0      M     Property Cover
# 1     AMI-00002   Joseph Wafula  41.0    NaN     Property Cover
# 2     AMI-00003     Grace Kamau  66.0      F       Health Cover
# 3     AMI-00004  Samuel Njoroge  45.0      F       Health Cover
# 4     AMI-00005   Collins Kamau  40.0      F  Motor Third-Party
#
#    sum_insured_kes   region   join_date
# 0           500000  Eldoret  2020-11-23
# 1          2000000  Mombasa  2020-02-12
# 2           800000  Nairobi  2020-01-26
# 3          5000000  Eldoret  2023-07-08
# 4          2000000  Mombasa  2019-06-12

# %%
# Even a "system-exported" file isn't always perfect -- check for gaps here too.
print("Missing values in policyholders (system export, still not perfect):")
policyholders.isna().sum()
# Out:
# Missing values in policyholders (system export, still not perfect):
# policy_number      0
# full_name          0
# age                7
# gender             7
# cover_type         0
# sum_insured_kes    0
# region             0
# join_date          0
# dtype: int64

# %% [markdown]
# Fetching data from a public API

# %% [markdown]
# An API call here is just an HTTP request that returns data (usually JSON) instead of a web page. We wrap it in a function that tries the live call first, and automatically falls back to a cached file if anything goes wrong — this "try live, fall back to cache" pattern is exactly what production systems do too, not just classroom demos.

# %%
def fetch_live_usd_kes_rate():
    """GET request to api.frankfurter.app, a free/keyless currency API.
    Returns a float rate, or raises an exception if the call fails
    (no internet, API down, etc.) -- the caller decides what to do next.
    """
    response = requests.get(API_URL, params={"from": "USD", "to": "KES"}, timeout=5)
    response.raise_for_status()   # turns a bad HTTP status (e.g. 404, 500) into an exception
    data = response.json()        # parse the JSON response body into a Python dict
    print("Raw API response:", data)
    return data["rates"]["KES"]

# %%
def get_usd_kes_rate():
    """Try the live API first; fall back to the cached JSON file if
    anything goes wrong."""
    try:
        rate = fetch_live_usd_kes_rate()
        print(f"Using LIVE rate: 1 USD = {rate} KES")
        return rate, "live"
    except (requests.RequestException, KeyError, ValueError) as e:
        # requests.RequestException catches network/HTTP problems;
        # KeyError/ValueError catch a malformed or unexpected response body.
        print(f"Live API call failed ({e.__class__.__name__}: {e}). Falling back to cached rate.")
        with open(FALLBACK_RATES_PATH, "r", encoding="utf-8") as f:
            cache = json.load(f)
        most_recent_date = max(cache["rates_by_date"])   # the latest cached date
        rate = cache["rates_by_date"][most_recent_date]
        print(f"Using CACHED rate from {most_recent_date}: 1 USD = {rate} KES ({cache['note']})")
        return rate, "cached"


usd_kes_rate, rate_source = get_usd_kes_rate()
# Out:
# Live API call failed (HTTPError: 404 Client Error: Not Found for url: https://api.frankfurter.dev/v1/latest?from=USD&to=KES). Falling back to cached rate.
# Using CACHED rate from 2024-08-31: 1 USD = 129.58 KES (offline fallback cache -- not live rates)

# %% [markdown]
# Joining claims + policyholders, converting to USD

# %% [markdown]
# Now bring everything together: clean the claims amounts, join in the policyholder details by policy_number, convert to USD using the rate from Section 2, and report the claims that get ceded (shared) with the reinsurer.

# %%
# Same cleaning pattern as Parts 3 & 4.
claims["claim_amount_kes"] = (
    claims["claim_amount_kes"].astype(str).str.replace(",", "", regex=False).str.strip()
)
claims["claim_amount_kes"] = pd.to_numeric(claims["claim_amount_kes"], errors="coerce").abs()
claims["claim_type"] = claims["claim_type"].astype(str).str.strip().str.lower().str.replace(" ", "-")
claims["region"] = claims["region"].astype(str).str.strip().str.title()
group_median = claims.groupby("claim_type")["claim_amount_kes"].transform("median")
claims["claim_amount_kes"] = claims["claim_amount_kes"].fillna(group_median)

# %%
# Join claims to policyholder master data on policy_number -- this is why
# loading BOTH sources mattered: the claims log alone doesn't know a
# policyholder's cover type or sum insured.
merged = claims.merge(policyholders, on="policy_number", how="left", suffixes=("", "_policy"))
print(f"Merged shape: {merged.shape}  "
      f"(claims: {claims.shape[0]}, policyholders matched: {merged['full_name'].notna().sum()})")

merged["claim_amount_usd"] = merged["claim_amount_kes"] / usd_kes_rate
# Out:
# Merged shape: (509, 16)  (claims: 509, policyholders matched: 509)

# %%
# Reinsurance treaty: anything over KES 500,000 gets ceded (shared) with
# the reinsurer -- report those specifically, in both currencies.
CESSION_THRESHOLD_KES = 500_000
ceded = merged[merged["claim_amount_kes"] > CESSION_THRESHOLD_KES].copy()
ceded = ceded.sort_values("claim_amount_kes", ascending=False)

print(f"Ceded claims (> KES {CESSION_THRESHOLD_KES:,}): {len(ceded)}")
print(f"Exchange rate used: 1 USD = {usd_kes_rate} KES (source: {rate_source})")
# Out:
# Ceded claims (> KES 500,000): 155
# Exchange rate used: 1 USD = 129.58 KES (source: cached)

# %%
ceded[["claim_id", "claim_type", "region", "claim_amount_kes", "claim_amount_usd"]].head(5).style.format({
    "claim_amount_kes": "{:,.0f}",
    "claim_amount_usd": "{:,.0f}",
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6de9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6de9f_level0_col0" class="col_heading level0 col0" >claim_id</th>
#       <th id="T_6de9f_level0_col1" class="col_heading level0 col1" >claim_type</th>
#       <th id="T_6de9f_level0_col2" class="col_heading level0 col2" >region</th>
#       <th id="T_6de9f_level0_col3" class="col_heading level0 col3" >claim_amount_kes</th>
#       <th id="T_6de9f_level0_col4" class="col_heading level0 col4" >claim_amount_usd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6de9f_level0_row0" class="row_heading level0 row0" >411</th>
#       <td id="T_6de9f_row0_col0" class="data row0 col0" >CLM-00179</td>
#       <td id="T_6de9f_row0_col1" class="data row0 col1" >property-fire</td>
#       <td id="T_6de9f_row0_col2" class="data row0 col2" >Nyeri</td>
#       <td id="T_6de9f_row0_col3" class="data row0 col3" >10,112,000</td>
#       <td id="T_6de9f_row0_col4" class="data row0 col4" >78,037</td>
#     </tr>
#     <tr>
#       <th id="T_6de9f_level0_row1" class="row_heading level0 row1" >91</th>
#       <td id="T_6de9f_row1_col0" class="data row1 col0" >CLM-00249</td>
#       <td id="T_6de9f_row1_col1" class="data row1 col1" >property-fire</td>
#       <td id="T_6de9f_row1_col2" class="data row1 col2" >Kisumu</td>
#       <td id="T_6de9f_row1_col3" class="data row1 col3" >8,307,000</td>
#       <td id="T_6de9f_row1_col4" class="data row1 col4" >64,107</td>
#     </tr>
#     <tr>
#       <th id="T_6de9f_level0_row2" class="row_heading level0 row2" >410</th>
#       <td id="T_6de9f_row2_col0" class="data row2 col0" >CLM-00206</td>
#       <td id="T_6de9f_row2_col1" class="data row2 col1" >motor-theft</td>
#       <td id="T_6de9f_row2_col2" class="data row2 col2" >Mombasa</td>
#       <td id="T_6de9f_row2_col3" class="data row2 col3" >4,656,000</td>
#       <td id="T_6de9f_row2_col4" class="data row2 col4" >35,931</td>
#     </tr>
#     <tr>
#       <th id="T_6de9f_level0_row3" class="row_heading level0 row3" >201</th>
#       <td id="T_6de9f_row3_col0" class="data row3 col0" >CLM-00184</td>
#       <td id="T_6de9f_row3_col1" class="data row3 col1" >property-fire</td>
#       <td id="T_6de9f_row3_col2" class="data row3 col2" >Nyeri</td>
#       <td id="T_6de9f_row3_col3" class="data row3 col3" >1,745,300</td>
#       <td id="T_6de9f_row3_col4" class="data row3 col4" >13,469</td>
#     </tr>
#     <tr>
#       <th id="T_6de9f_level0_row4" class="row_heading level0 row4" >251</th>
#       <td id="T_6de9f_row4_col0" class="data row4 col0" >CLM-00297</td>
#       <td id="T_6de9f_row4_col1" class="data row4 col1" >property-fire</td>
#       <td id="T_6de9f_row4_col2" class="data row4 col2" >Kisumu</td>
#       <td id="T_6de9f_row4_col3" class="data row4 col3" >1,739,000</td>
#       <td id="T_6de9f_row4_col4" class="data row4 col4" >13,420</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_ceded_usd = ceded["claim_amount_usd"].sum()
print(f"Total ceded exposure: USD {total_ceded_usd:,.0f}")
# Out:
# Total ceded exposure: USD 1,162,285

# %% [markdown]
# What we just built: one working DataFrame assembled from three different kinds of source — a local CSV, a local JSON file, and a live web API — with a safety net so a network hiccup never breaks the whole analysis.
